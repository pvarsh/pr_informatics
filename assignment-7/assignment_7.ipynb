# %%
import numpy as np
from matplotlib import pyplot as plt
import pylab
import pandas as pd
from datetime import datetime
import sys
import matplotlib.cm as cm

### settings
# %matplotlib inline

# %%
### read data
in_file = "311_Service_Requests_from_2010_to_Present.csv"
with open(in_file, 'r') as f:
    df = pd.read_csv(f, index_col = ['Unique Key'], parse_dates=['Created Date', 'Closed Date'])

# %%
df
# Out:
#                   Created Date         Closed Date Agency  \
# Unique Key
# 26233351   2013-08-31 23:59:00 2013-09-01 00:50:02   NYPD
# 26233336   2013-08-31 23:58:22 2013-09-01 00:13:30   NYPD
# 26233332   2013-08-31 23:57:49 2013-09-01 03:00:17   NYPD
# 26235054   2013-08-31 23:57:33 2013-09-01 06:40:20   NYPD
# 26234387   2013-08-31 23:56:08 2013-09-01 02:59:14   NYPD
# 26234813   2013-08-31 23:55:11 2013-09-01 02:33:46   NYPD
# 26233896   2013-08-31 23:54:38 2013-09-01 08:12:39   NYPD
# 26234850   2013-08-31 23:53:31 2013-09-01 01:06:27   NYPD
# 26234577   2013-08-31 23:53:18                 NaT  DOHMH
# 26237118   2013-08-31 23:53:00 2013-09-07 12:00:00   DSNY
# 26235681   2013-08-31 23:52:34 2013-09-01 06:39:32   NYPD
# 26235168   2013-08-31 23:51:00 2013-09-01 01:25:00    DOT
# 26236731   2013-08-31 23:50:05 2013-09-01 06:39:05   NYPD
# 26236135   2013-08-31 23:50:04 2013-09-01 04:26:55   NYPD
# 26236459   2013-08-31 23:50:00 2013-09-03 11:35:00    DOT
# ...

# %%
grouped = df['Agency'].groupby(df['Agency'])
pr1_1 = grouped.count()
print pr1_1.head()
# Out:
# Agency
# 3-1-1     261
# CAU         2
# CCRB        2
# CHALL     689
# COIB        1
# Name: Agency, dtype: int64

# %%
### Problem 1
pr1_agencies = ['NYPD','DOT','DOB','TLC','DPR']
print pr1_1[pr1_agencies]
# Out:
# NYPD    56671
# DOT     64695
# DOB     21998
# TLC      5451
# DPR     25681
# Name: Agency, dtype: int64

# %%
colors = [0.5/float(len(pr1_agencies)) * k for k in range(len(pr1_agencies))]
#colors = np.random.randn(len(pr1_agencies))
x = plt.figure(1)
xpos = [1.5*x for x in range (0, len(pr1_agencies))]
fig, ax = plt.subplots()
plt.bar(xpos, pr1_1[pr1_agencies], align = 'center', width = 1.2, color = cm.Accent(colors), alpha = 0.7)
ax.set_xticklabels( pr1_agencies )
plt.show()

# %%
x = np.linspace(0, 1)
y = x**2
plt.scatter(x, y, c = y, cmap = plt.get_cmap('Accent'))

# %%
tbar = pr1_1[pr1_agencies]
print tbar
tbar = tbar/(max(tbar))
print tbar
#pr1_1[pr1_agencies].plot(kind = 'bar', colormap = 'Accent')
fig, ax = plt.subplots()
ax.set_xticklabels( ('G1', 'G2', 'G3', 'G4', 'G5') )
#tbar.plot(kind = 'bar', colormap = 'gist_rainbow')
# Out:
# NYPD    56671
# DOT     64695
# DOB     21998
# TLC      5451
# DPR     25681
# Name: Agency, dtype: int64
# NYPD    0.875972
# DOT     1.000000
# DOB     0.340026
# TLC     0.084257
# DPR     0.396955
# Name: Agency, dtype: float64

# %%
# ?plt.subplots()

# %%
colors = np.random.randn(len(pr1_agencies))

# %%
print colors
# Out:
# [ 0.36279341 -0.49112773  2.48130512  1.63291921 -0.27518671]

# %%
# ?np.random.randn

# %%
"""
Simple demo of a horizontal bar chart.
"""
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.barh(y_pos, performance, xerr=error, align='center', alpha=0.4)
plt.yticks(y_pos, people)
plt.xlabel('Performance')
plt.title('How fast do you want to go today?')

plt.show()

# %%
fig = plt.figure()
# Out:
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
