# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys

# %matplotlib inline

# %%
data_file = sys.argv[1]
data_file = "stocks.dat"

# %%
with open(data_file, 'r') as f:
    stocks = pd.read_csv(f)
stocks.sort(columns = ['month'], inplace = True)
stocks.index = range(stocks.shape[0])

# %% [markdown]
# ###### Problem 1a

# %%
fig, ax = plt.subplots()
ax.plot(stocks.apple, lw = .5)
xticks = [int(tick) for tick in ax.get_xticks()]
print xticks
xticks = [x * 3 for x in range(int(stocks.shape[0]/3))]
ax.set_xticks(xticks)
xticklabels = list(stocks.month[xticks])
#print stocks.month[xticks]
ax.set_xticklabels(xticklabels, rotation = 45, fontsize = 9)
plt.show()
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35]

# %% [markdown]
# ###### Problem 1b

# %%
fig, ax = plt.subplots()
ax.plot(stocks.apple, lw = .5)
ax.plot(stocks.microsoft, lw = .5)
xticks = [int(tick) for tick in ax.get_xticks()]
print xticks
xticks = [x * 3 for x in range(int(stocks.shape[0]/3))]
ax.set_xticks(xticks)
xticklabels = list(stocks.month[xticks])
#print stocks.month[xticks]
ax.set_xticklabels(xticklabels, rotation = 45, fontsize = 9)
plt.show()
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35]

# %% [markdown]
# ###### Proble 1c

# %%
fig, [ax1, ax2] = plt.subplots(ncols = 2)
ax1.plot(stocks.apple, lw = .5)
ax2.plot(stocks.microsoft, lw = .5)
xticks = [int(tick) for tick in ax.get_xticks()]
print xticks
xticks = [x * 3 for x in range(int(stocks.shape[0]/3))]
ax.set_xticks(xticks)
xticklabels = list(stocks.month[xticks])
#print stocks.month[xticks]
ax.set_xticklabels(xticklabels, rotation = 45, fontsize = 9)
plt.show()
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30]

# %%
plt.subplots()
